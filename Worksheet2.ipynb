# %% [markdown]
# <a href="https://colab.research.google.com/github/Amib1354/Amit_Baniya_2509454/blob/main/Worksheet2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#3.1 Exercise
#Problem_1
import pandas as pd
dataset = pd.read_csv("C:/Users/Amit Baniya/Downloads/bank.csv")
print(dataset.head())
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
print(dataset.info())

object_columns = dataset.select_dtypes(include=["object"]).columns
print("Columns containing object datatype:-")
print(object_columns)

for col in object_columns:
    print("\nColumn:-",col)
    print(dataset[col].unique())

print("\nNull values in each column:-")
print(dataset.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# None
# Columns containing object datatype:-
# ...

# %%
numeric_df=dataset.drop(columns=object_columns)

numeric_df.to_csv("C:/Users/Amit Baniya/Downloads/banknumericdata.csv", index=False)

# %%
bank_numeric = pd.read_csv("C:/Users/Amit Baniya/Downloads/banknumericdata.csv")
print(bank_numeric.describe())
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
#Problem_2
import pandas as pd
medical_data = pd.read_csv("C:/Users/Amit Baniya/Downloads/medical_students_dataset.csv")
print(medical_data)
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927409  99.928405          O  42.175189
#
# ...

# %%
print(medical_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student ID      180000 non-null  float64
#  1   Age             180000 non-null  float64
#  2   Gender          180000 non-null  object
#  3   Height          180000 non-null  float64
#  4   Weight          180000 non-null  float64
#  5   Blood Type      180000 non-null  object
#  6   BMI             180000 non-null  float64
#  7   Temperature     180000 non-null  float64
#  8   Heart Rate      180000 non-null  float64
#  9   Blood Pressure  180000 non-null  float64
#  10  Cholesterol     180000 non-null  float64
#  11  Diabetes        180000 non-null  object
#  12  Smoking         180000 non-null  object
# dtypes: float64(9), object(4)
# memory usage: 19.8+ MB
# None

# %%
print("\n Columns with missing values:-")
print(medical_data.isnull().sum())
# Out:
#  Columns with missing values:-
# Student ID        20000
# Age               20000
# Gender            20000
# Height            20000
# Weight            20000
# Blood Type        20000
# BMI               20000
# Temperature       20000
# Heart Rate        20000
# Blood Pressure    20000
# Cholesterol       20000
# Diabetes          20000
# Smoking           20000
# dtype: int64

# %%
numeric_cols = ["Age","Height","Weight","BMI","Temperature","Heart Rate","Cholesterol"]

for col in numeric_cols:
    medical_data[col] = medical_data[col].fillna(medical_data[col].mean())

cat_cols = ["Student ID","Gender","Blood Type","Blood Pressure","Diabetes","Smoking"]

for col in cat_cols:
    medical_data[col] = medical_data[col].fillna(medical_data[col].mode()[0])

# %%
print(medical_data.isnull().sum())
# Out:
# Student ID        0
# Age               0
# Gender            0
# Height            0
# Weight            0
# Blood Type        0
# BMI               0
# Temperature       0
# Heart Rate        0
# Blood Pressure    0
# Cholesterol       0
# Diabetes          0
# Smoking           0
# dtype: int64

# %%
print("The number of duplicated rows is:-", medical_data.duplicated().sum())

medical_data = medical_data.drop_duplicates()
print("The number of duplicate rows after removing is:-",medical_data.duplicated().sum())
# Out:
# The number of duplicated rows is:- 12614
# The number of duplicate rows after removing is:- 0

# %%
#3.2 Exercise

#Problem-1
import pandas as pd;
data = pd.read_csv("C:/Users/Amit Baniya/Downloads/Titanic-Dataset.csv")
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
filtered_data = df[df['Pclass']==1]
print(filtered_data)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
mean_fare = df['Fare'].mean()
print("The mean fare for the given data is:- ",mean_fare)
median_fare = df['Fare'].median()
print("The median fare for the given data is:- ",median_fare)
max_fare = df['Fare'].max()
print("The maximum fare for the given data is:- ",max_fare)
min_fare = df['Fare'].min()
print("The minimum fare for the given data is:- ",min_fare)
# Out:
# The mean fare for the given data is:-  32.204207968574636
# The median fare for the given data is:-  14.4542
# The maximum fare for the given data is:-  512.3292
# The minimum fare for the given data is:-  0.0

# %%
#Problem-2
null_count = df['Age'].isnull().sum()
print("The null values contained in the age column of the DataFrame are:- ",null_count)
# Out:
# The null values contained in the age column of the DataFrame are:-  177

# %%
df_without_age = df.dropna(subset=['Age'])
print(df_without_age)
null_count_after = df_without_age['Age'].isnull().sum()
print("The null values contained in the age column of the DataFrame are:- ",null_count_after)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Problem-3
embarked_dummies = pd.get_dummies(df['Embarked'],prefix='Embarked')
df_with_dummies = pd.concat([df, embarked_dummies], axis = 1)
df_with_dummies = df_with_dummies.drop(columns=['Embarked'])
print(df_with_dummies.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0      0         A/5 21171   7.2500   NaN       False       False        True
# 1      0          PC 17599  71.2833   C85        True       False       False
# 2      0  STON/O2. 3101282   7.9250   NaN       False       False        True
# ...

# %%
#Problem-4
import matplotlib.pyplot as plt
survival_by_sex = df.groupby('Sex')['Survived'].mean()
print(survival_by_sex)
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
plt.bar(survival_by_sex.index,survival_by_sex.values, color = ['yellow','lightblue'])
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Gender')
plt.ylim(0,1)
plt.show()

# %%
#Problem-5
survival_by_sex_embarked = df_without_age.groupby(['Sex','Embarked'])['Survived'].mean()
print(survival_by_sex_embarked)
# Out:
# Sex     Embarked
# female  C           0.901639
#         Q           0.583333
#         S           0.715054
# male    C           0.347826
#         Q           0.062500
#         S           0.184783
# Name: Survived, dtype: float64

# %%
survival_by_sex_embarked.plot(kind='bar',color=['green','maroon'])
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Sex and Port of Embarkation')
plt.ylim(0,1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2820669854.py in <cell line: 0>()
# ----> 1 survival_by_sex_embarked.plot(kind='bar',color=['green','maroon'])
#       2 plt.ylabel('Survival Rate')
#       3 plt.title('Survival Rate by Sex and Port of Embarkation')
#       4 plt.ylim(0,1)
#       5 plt.show()
#
# NameError: name 'survival_by_sex_embarked' is not defined
